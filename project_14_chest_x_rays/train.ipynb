# %%
import os
import gc
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from shutil import copyfile
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
os.makedirs('/home/kong/14_disease_2022/tmp/data_ex7/images/train', exist_ok=True)
os.makedirs('/home/kong/14_disease_2022/tmp/data_ex7/images/valid', exist_ok=True)
os.makedirs('/home/kong/14_disease_2022/tmp/data_ex7/images/test', exist_ok=True)


os.makedirs('/home/kong/14_disease_2022/tmp/data_ex7/labels/train', exist_ok=True)
os.makedirs('/home/kong/14_disease_2022/tmp/data_ex7/labels/valid', exist_ok=True)
os.makedirs('/home/kong/14_disease_2022/tmp/data_ex7/labels/test', exist_ok=True)

# %%
class_name = ['Aortic enlargement',
 'Atelectasis',
 'Calcification',
 'Cardiomegaly',
 'Consolidation',
 'ILD',
 'Infiltration',
 'Lung Opacity',
 'Nodule/Mass',
 'Other lesion',
 'Pleural effusion',
 'Pleural thickening',
 'Pneumothorax',
 'Pulmonary fibrosis']

col_name = ['name','Aortic enlargement',
 'Atelectasis',
 'Calcification',
 'Cardiomegaly',
 'Consolidation',
 'ILD',
 'Infiltration',
 'Lung Opacity',
 'Nodule/Mass',
 'Other lesion',
 'Pleural effusion',
 'Pleural thickening',
 'Pneumothorax',
 'Pulmonary fibrosis']

dict_class = {'Aortic enlargement': 0,
 'Atelectasis': 1,
 'Calcification': 2,
 'Cardiomegaly': 3,
 'Consolidation': 4,
 'ILD': 5,
 'Infiltration': 6,
 'Lung Opacity': 7,
 'Nodule/Mass': 8,
 'Other lesion': 9,
 'Pleural effusion': 10,
 'Pleural thickening': 11,
 'Pneumothorax': 12,
 'Pulmonary fibrosis': 13}

# %%
dir_list = os.listdir("/home/kong/14_disease_2022/dataset/label_7")

# %%
len(dir_list)
# Out:
# 4394

# %%
from sklearn.model_selection import train_test_split

train_dir_list, test_dir_list = train_test_split(dir_list, test_size=0.1, random_state=42)
train_dir_list, val_dir_list = train_test_split(train_dir_list, test_size=0.1, random_state=42)

# %%
print(len(train_dir_list))
print(len(test_dir_list))
print(len(val_dir_list))
# Out:
# 3558
# 440
# 396

# %%
train_dir_list
# Out:
# ['c854dff7593a38e6e7a83330ff32ac86.txt',
#  'c25a87784e4a9dd01911f626cbd1faeb.txt',
#  '7661ae717d26893100f399e76e02c438.txt',
#  '30a08276cab4bd3ba231b2307341b987.txt',
#  '417de085be6029490ca2690608d65e57.txt',
#  '1fec2347206230bc4721f66d8e90971a.txt',
#  'c3d222900b4131b148a9943db0e1bcc6.txt',
#  'b4c6f7fd99fa215a9634736b8a0cd5d1.txt',
#  'add6e79a3c93a11bdd9a74886b480840.txt',
#  '6692df8a8c5f641eff181a2f589bfe80.txt',
#  'be66657e907a732207237b75b7e105c4.txt',
#  '41a3987fef185ed06ea962df3493f57a.txt',
#  '1250c704cc9307bf84b43f1aca4d997b.txt',
#  '6f322939176779d7af4f7c76701fa91d.txt',
#  '82624b37dc4d0169f3fe6fd87dcb5208.txt',
#  'a5c7b10a238b041fc8d10afd9cc12569.txt',
#  'b5be61351d358e354a42633e5d853352.txt',
#  '6452a9e9489dadc789cb44af7d3dadab.txt',
#  '4e0856fe29f4d2eecc45dcac43c39c1e.txt',
#  '803179ef55f8ecf356363cf194b4ff33.txt',
#  '717b848dae42dc6c33d6d3a5754e690b.txt',
#  '2f3bb25eb6ae1a19b982c6ba56f725e2.txt',
#  '6e47a3c35eecd25bf915998f192b32d1.txt',
# ...

# %%
for id_name in tqdm(range(len(dir_list))):
    name_ = dir_list[id_name].split('.txt')[0]
    if dir_list[id_name] in train_dir_list:
        copyfile(f"/ramdisk/vinbigdata-chest-xray-png/train/{name_}.png"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/images/train/{name_}.jpg")
        copyfile(f"/home/kong/14_disease_2022/dataset/label_7/{name_}.txt"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/labels/train/{name_}.txt")
    elif dir_list[id_name] in test_dir_list:
        copyfile(f"/ramdisk/vinbigdata-chest-xray-png/train/{name_}.png"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/images/test/{name_}.jpg")
        copyfile(f"/home/kong/14_disease_2022/dataset/label_7/{name_}.txt"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/labels/test/{name_}.txt")
    elif dir_list[id_name] in val_dir_list:
        copyfile(f"/ramdisk/vinbigdata-chest-xray-png/train/{name_}.png"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/images/valid/{name_}.jpg")
        copyfile(f"/home/kong/14_disease_2022/dataset/label_7/{name_}.txt"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/labels/valid/{name_}.txt")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4394/4394 [00:10<00:00, 434.42it/s]

# %%
dir_list = os.listdir("/home/kong/14_disease_2022/dataset/label_aug_7")

# %%
len(dir_list)
# Out:
# 13182

# %%
from sklearn.model_selection import train_test_split

train_dir_list, test_dir_list = train_test_split(dir_list, test_size=0.1, random_state=42)
train_dir_list, val_dir_list = train_test_split(train_dir_list, test_size=0.1, random_state=42)

# %%
print(len(train_dir_list))
print(len(test_dir_list))
print(len(val_dir_list))
# Out:
# 10676
# 1319
# 1187

# %%
train_dir_list
# Out:
# ['c4c1ef63bd568c89beb4ae3ab9eeb1bb_HorizontalFlip.txt',
#  '0464251a01ee7eeedd2a537dafc82844_HorizontalFlip.txt',
#  '2ceaa4c6e93b4496df1831cccc3e433a_VerticalFlip.txt',
#  '0f45742c4d100eeee221f8853d79c9d4_vh.txt',
#  '3052424d097d8b94d387a20248639d47_HorizontalFlip.txt',
#  '30d70dcb9b7a5d7e9028326954feaa35_HorizontalFlip.txt',
#  '414615baf78e32f3405cbcf5b742895d_HorizontalFlip.txt',
#  'a9b3444f50e7ab612641a6fe1e4f8cb9_HorizontalFlip.txt',
#  '2596fb668f0ec31ac6622ea546e600cf_VerticalFlip.txt',
#  '74a6dc1a51dffd964baef5089fc4d1b6_VerticalFlip.txt',
#  '2a364dea24600221fb6208567bda008b_vh.txt',
#  'ddfc9d530d66058f1dcec6b2685bc254_vh.txt',
#  'f7dd175ca0962155ec39311b997a5288_HorizontalFlip.txt',
#  '703e3e8b33821c0b0553c5d534a5419f_VerticalFlip.txt',
#  '13776ecb39222a7aaace2d9721abebbe_vh.txt',
#  '971e2965c2e5149f64be489d589dc3d0_vh.txt',
#  '6acc13406eda521dedfca734ddbe3e25_HorizontalFlip.txt',
#  '63803ddfb3ea3bb435ff62c45ba78fde_VerticalFlip.txt',
# ...

# %%
for id_name in tqdm(range(len(dir_list))):
    name_ = dir_list[id_name].split('.txt')[0]
    if dir_list[id_name] in train_dir_list:
        copyfile(f"/home/kong/14_disease_2022/dataset/image_aug_7/{name_}.jpg"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/images/train/{name_}.jpg")
        copyfile(f"/home/kong/14_disease_2022/dataset/label_aug_7/{name_}.txt"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/labels/train/{name_}.txt")
    elif dir_list[id_name] in test_dir_list:
        copyfile(f"/home/kong/14_disease_2022/dataset/image_aug_7/{name_}.jpg"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/images/test/{name_}.jpg")
        copyfile(f"/home/kong/14_disease_2022/dataset/label_aug_7/{name_}.txt"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/labels/test/{name_}.txt")
    elif dir_list[id_name] in val_dir_list:
        copyfile(f"/home/kong/14_disease_2022/dataset/image_aug_7/{name_}.jpg"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/images/valid/{name_}.jpg")
        copyfile(f"/home/kong/14_disease_2022/dataset/label_aug_7/{name_}.txt"
                 , f"/home/kong/14_disease_2022/tmp/data_ex7/labels/valid/{name_}.txt")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13182/13182 [00:22<00:00, 596.79it/s]

# %%
class_name = ['Aortic enlargement',
     'Atelectasis',
     'Calcification',
     'Cardiomegaly',
     'Consolidation',
     'ILD',
     'Infiltration',
     'Lung Opacity',
     'Nodule/Mass',
     'Other lesion',
     'Pleural effusion',
     'Pleural thickening',
     'Pneumothorax',
     'Pulmonary fibrosis']

# %%
len(class_name)
# Out:
# 14

# %%
#.yaml dosyası oluştur
import yaml

data_yaml = dict(
    train = '/home/kong/14_disease_2022/tmp/data_ex7/images/train',
    val = '/home/kong/14_disease_2022/tmp/data_ex7/images/valid',
    nc = len(class_name),
    names = class_name
)

# Dosyayı yolov5/data/ klasöründe  oluşturma
with open('/home/kong/14_disease_2022/tmp/yolov5/data/data_ex7.yaml', 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=True)
    
# %cat /home/kong/14_disease_2022/tmp/yolov5/data/data_ex7.yaml
# Out:
# {names: [Aortic enlargement, Atelectasis, Calcification, Cardiomegaly, Consolidation,
#     ILD, Infiltration, Lung Opacity, Nodule/Mass, Other lesion, Pleural effusion,
#     Pleural thickening, Pneumothorax, Pulmonary fibrosis], nc: 14, train: /home/kong/14_disease_2022/tmp/data_ex7/images/train,
#   val: /home/kong/14_disease_2022/tmp/data_ex7/images/valid}

# %%
# %cd /home/kong/14_disease_2022/tmp/yolov5/

# %%
# eğitim görüntü yolu
# resimlerin gelmesi gerekn boyut
IMG_SIZE = 640
# her seferinde çekilecek sayısı
BATCH_SIZE = 16
# kaç sefer veriler verilecek
EPOCHS = 50

# %%
# !python train.py --img {IMG_SIZE} \
                 --batch {BATCH_SIZE} \
                 --epochs {EPOCHS} \
                 --data data_ex1.yaml \
                 --weights yolov5x.pt \
                --freeze 13
